# %%
import gym
from stable_baselines3 import PPO, SAC, A2C
from stable_baselines3.common.evaluation import evaluate_policy

env_id = "BipedalWalker-v3"
timesteps = 200_000
eval_episodes = 10

algorithms_dict = {
    "PPO": PPO,
    "SAC": SAC,
    "A2C": A2C
}
results = {}



for name, algo in algorithms_dict.items():
    print(f"Training {name}")

    env = gym.make(env_id)
    model = algo("MlpPolicy", env, verbose=1)
    model.learn(total_timesteps=timesteps)
    mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=eval_episodes)
    results[name] = (mean_reward, std_reward)
    print(f"{name} - Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
    env.close()
# Out:
# Training PPO
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Acer\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.4     |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    fps             | 705      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0084170075 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | -0.0123      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.9         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 1            |
# |    value_loss           | 259          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0073936665 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00814     |
# |    std                  | 1            |
# |    value_loss           | 397          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 4            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0124674775 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00883     |
# |    std                  | 0.993        |
# |    value_loss           | 31.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 372         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010736664 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.993       |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014015834 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.978       |
# |    value_loss           | 0.8         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 421          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 7            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0064715063 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.58        |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.48         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0023      |
# |    std                  | 0.975        |
# |    value_loss           | 48.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 446         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 8           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012477463 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.967       |
# |    value_loss           | 21.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 9           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009177396 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.28        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00392    |
# |    std                  | 0.96        |
# |    value_loss           | 24.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 528          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 10           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0063128276 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.49        |
# |    explained_variance   | 0.05         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00525     |
# |    std                  | 0.95         |
# |    value_loss           | 30.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 11          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009178424 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0408      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.94        |
# |    value_loss           | 0.211       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 581         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 12          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013771758 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.41       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0891      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.931       |
# |    value_loss           | 0.424       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 619         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 13          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009953853 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00134     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00776    |
# |    std                  | 0.9         |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 628         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 14          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005083138 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00403    |
# |    std                  | 0.901       |
# |    value_loss           | 21          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 649          |
# |    ep_rew_mean          | -110         |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 15           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0073575317 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.24        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.755        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 0.894        |
# |    value_loss           | 17.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 670         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 16          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008989232 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00798     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.878       |
# |    value_loss           | 0.0636      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 694         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 17          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012245066 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00111    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.864       |
# |    value_loss           | 0.184       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 712         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 18          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006257332 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.33        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00427    |
# |    std                  | 0.863       |
# |    value_loss           | 32.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 19          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009874975 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.05       |
# |    explained_variance   | 0.364       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00647    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.852       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 746         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 20          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011061592 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0361      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.838       |
# |    value_loss           | 0.0692      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 21          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010295218 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | -0.171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00552    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.82        |
# |    value_loss           | 0.0818      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 791         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 22          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010232479 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0398      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.811       |
# |    value_loss           | 0.087       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 805        |
# |    ep_rew_mean          | -105       |
# | time/                   |            |
# |    fps                  | 450        |
# |    iterations           | 23         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00818135 |
# |    clip_fraction        | 0.0793     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.82      |
# |    explained_variance   | 0.705      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0155     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00916   |
# |    std                  | 0.806      |
# |    value_loss           | 0.0525     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 832        |
# |    ep_rew_mean          | -104       |
# | time/                   |            |
# |    fps                  | 447        |
# |    iterations           | 24         |
# |    time_elapsed         | 109        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00824146 |
# |    clip_fraction        | 0.0939     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.78      |
# |    explained_variance   | 0.595      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00183    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00877   |
# |    std                  | 0.797      |
# |    value_loss           | 0.0708     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 833         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 25          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010638859 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0408      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.79        |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 26          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005322695 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0052     |
# |    std                  | 0.79        |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 857         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 27          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011872912 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0078      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.779       |
# |    value_loss           | 0.0627      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 880         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 28          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009589855 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00604     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.769       |
# |    value_loss           | 0.0907      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 891         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 29          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009167818 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.763       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 901        |
# |    ep_rew_mean          | -100       |
# | time/                   |            |
# |    fps                  | 452        |
# |    iterations           | 30         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01364717 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.55      |
# |    explained_variance   | 0.683      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0178     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0148    |
# |    std                  | 0.752      |
# |    value_loss           | 0.0875     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 912         |
# |    ep_rew_mean          | -99.6       |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 31          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011528678 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00577     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.739       |
# |    value_loss           | 0.0663      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | -98.1       |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 32          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009606637 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0239      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.734       |
# |    value_loss           | 0.0861      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 941         |
# |    ep_rew_mean          | -97.5       |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 33          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010825714 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0188      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.729       |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 950         |
# |    ep_rew_mean          | -96.8       |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 34          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008431902 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.045       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 0.724       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 967        |
# |    ep_rew_mean          | -95.3      |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 35         |
# |    time_elapsed         | 160        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.00971224 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.35      |
# |    explained_variance   | 0.768      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0262     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0128    |
# |    std                  | 0.718      |
# |    value_loss           | 0.124      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 976         |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 36          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010887603 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0171      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.709       |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 984         |
# |    ep_rew_mean          | -94         |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 37          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011688678 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.065       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.7         |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -93         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 38          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009815704 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0334      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.688       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -91.2       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 39          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014794949 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0824      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.68        |
# |    value_loss           | 0.166       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+03   |
# |    ep_rew_mean          | -90.1      |
# | time/                   |            |
# |    fps                  | 442        |
# |    iterations           | 40         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00979051 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.07      |
# |    explained_variance   | 0.794      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0579     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.664      |
# |    value_loss           | 0.129      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | -89        |
# | time/                   |            |
# |    fps                  | 441        |
# |    iterations           | 41         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00950362 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4         |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0911     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0101    |
# |    std                  | 0.655      |
# |    value_loss           | 0.164      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | -86.2      |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 42         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01089741 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 0.778      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.128      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0117    |
# |    std                  | 0.648      |
# |    value_loss           | 0.292      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | -84.8      |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 43         |
# |    time_elapsed         | 199        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00886954 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.9       |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.121      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0103    |
# |    std                  | 0.639      |
# |    value_loss           | 0.264      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -83.3       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 44          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012951464 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0774      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.634       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -81.7       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 45          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010968696 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0863      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.629       |
# |    value_loss           | 0.235       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -78.4       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 46          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014217073 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.099       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.622       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07e+03     |
# |    ep_rew_mean          | -76.6        |
# | time/                   |              |
# |    fps                  | 439          |
# |    iterations           | 47           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0100765135 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.74        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.102        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 0.616        |
# |    value_loss           | 0.261        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 48          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014054317 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0856      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.604       |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 49          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009879745 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00999    |
# |    std                  | 0.601       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09e+03     |
# |    ep_rew_mean          | -72.2        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 50           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0059951874 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.63        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00944     |
# |    std                  | 0.601        |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -70.4       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 51          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013038363 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.587       |
# |    value_loss           | 0.332       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | -69.4       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 52          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012083828 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.586       |
# |    value_loss           | 2.31        |
# -----------------------------------------
# -----------------------------------------
# ...
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 37700    |
# |    time_elapsed       | 491      |
# |    total_timesteps    | 188500   |
# | train/                |          |
# |    entropy_loss       | -2.42    |
# |    explained_variance | -0.0969  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37699    |
# |    policy_loss        | -0.091   |
# |    std                | 0.449    |
# |    value_loss         | 0.0171   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 130      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 37800    |
# |    time_elapsed       | 492      |
# |    total_timesteps    | 189000   |
# | train/                |          |
# |    entropy_loss       | -2.4     |
# |    explained_variance | -7.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37799    |
# |    policy_loss        | -0.166   |
# |    std                | 0.446    |
# |    value_loss         | 0.0212   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 130      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 37900    |
# |    time_elapsed       | 494      |
# |    total_timesteps    | 189500   |
# | train/                |          |
# |    entropy_loss       | -2.39    |
# |    explained_variance | -0.562   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37899    |
# |    policy_loss        | 0.953    |
# |    std                | 0.446    |
# |    value_loss         | 0.0955   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 147      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38000    |
# |    time_elapsed       | 495      |
# |    total_timesteps    | 190000   |
# | train/                |          |
# |    entropy_loss       | -2.38    |
# |    explained_variance | -353     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37999    |
# |    policy_loss        | -3.36    |
# |    std                | 0.444    |
# |    value_loss         | 4.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 147      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38100    |
# |    time_elapsed       | 496      |
# |    total_timesteps    | 190500   |
# | train/                |          |
# |    entropy_loss       | -2.41    |
# |    explained_variance | -10.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38099    |
# |    policy_loss        | 0.0958   |
# |    std                | 0.447    |
# |    value_loss         | 0.0944   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 147       |
# |    ep_rew_mean        | -108      |
# | time/                 |           |
# |    fps                | 383       |
# |    iterations         | 38200     |
# |    time_elapsed       | 498       |
# |    total_timesteps    | 191000    |
# | train/                |           |
# |    entropy_loss       | -2.39     |
# |    explained_variance | -5.72e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38199     |
# |    policy_loss        | -2.43     |
# |    std                | 0.445     |
# |    value_loss         | 5.85      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 158      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38300    |
# |    time_elapsed       | 499      |
# |    total_timesteps    | 191500   |
# | train/                |          |
# |    entropy_loss       | -2.38    |
# |    explained_variance | -8.11    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38299    |
# |    policy_loss        | -1.06    |
# |    std                | 0.443    |
# |    value_loss         | 0.276    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 158      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38400    |
# |    time_elapsed       | 501      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -2.39    |
# |    explained_variance | -2.19    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38399    |
# |    policy_loss        | -0.286   |
# |    std                | 0.445    |
# |    value_loss         | 0.0347   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 158      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38500    |
# |    time_elapsed       | 502      |
# |    total_timesteps    | 192500   |
# | train/                |          |
# |    entropy_loss       | -2.39    |
# |    explained_variance | -2.19    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38499    |
# |    policy_loss        | 0.0426   |
# |    std                | 0.445    |
# |    value_loss         | 0.00341  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 38600    |
# |    time_elapsed       | 503      |
# |    total_timesteps    | 193000   |
# | train/                |          |
# |    entropy_loss       | -2.4     |
# |    explained_variance | -3.05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38599    |
# |    policy_loss        | -0.0142  |
# |    std                | 0.445    |
# |    value_loss         | 0.00227  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 38700    |
# |    time_elapsed       | 505      |
# |    total_timesteps    | 193500   |
# | train/                |          |
# |    entropy_loss       | -2.38    |
# |    explained_variance | 0.236    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38699    |
# |    policy_loss        | -0.108   |
# |    std                | 0.443    |
# |    value_loss         | 0.00819  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 173      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 38800    |
# |    time_elapsed       | 506      |
# |    total_timesteps    | 194000   |
# | train/                |          |
# |    entropy_loss       | -2.38    |
# |    explained_variance | 0.424    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38799    |
# |    policy_loss        | -0.0519  |
# |    std                | 0.443    |
# |    value_loss         | 0.0012   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 189      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 38900    |
# |    time_elapsed       | 508      |
# |    total_timesteps    | 194500   |
# | train/                |          |
# |    entropy_loss       | -2.39    |
# |    explained_variance | -6.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38899    |
# |    policy_loss        | 1.06     |
# |    std                | 0.445    |
# |    value_loss         | 0.203    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 189      |
# |    ep_rew_mean        | -108     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39000    |
# |    time_elapsed       | 509      |
# |    total_timesteps    | 195000   |
# | train/                |          |
# |    entropy_loss       | -2.37    |
# |    explained_variance | 0.573    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38999    |
# |    policy_loss        | 0.213    |
# |    std                | 0.442    |
# |    value_loss         | 0.0349   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 189       |
# |    ep_rew_mean        | -108      |
# | time/                 |           |
# |    fps                | 382       |
# |    iterations         | 39100     |
# |    time_elapsed       | 510       |
# |    total_timesteps    | 195500    |
# | train/                |           |
# |    entropy_loss       | -2.35     |
# |    explained_variance | -2.23e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39099     |
# |    policy_loss        | 0.222     |
# |    std                | 0.439     |
# |    value_loss         | 0.165     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 205      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39200    |
# |    time_elapsed       | 512      |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | -2.35    |
# |    explained_variance | -5.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39199    |
# |    policy_loss        | -1.31    |
# |    std                | 0.439    |
# |    value_loss         | 0.514    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 205      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39300    |
# |    time_elapsed       | 513      |
# |    total_timesteps    | 196500   |
# | train/                |          |
# |    entropy_loss       | -2.32    |
# |    explained_variance | -350     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39299    |
# |    policy_loss        | -2.17    |
# |    std                | 0.437    |
# |    value_loss         | 0.359    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 205      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39400    |
# |    time_elapsed       | 514      |
# |    total_timesteps    | 197000   |
# | train/                |          |
# |    entropy_loss       | -2.3     |
# |    explained_variance | 0.607    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39399    |
# |    policy_loss        | -0.126   |
# |    std                | 0.435    |
# |    value_loss         | 0.0278   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39500    |
# |    time_elapsed       | 516      |
# |    total_timesteps    | 197500   |
# | train/                |          |
# |    entropy_loss       | -2.29    |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39499    |
# |    policy_loss        | -77.2    |
# |    std                | 0.433    |
# |    value_loss         | 1.78e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39600    |
# |    time_elapsed       | 517      |
# |    total_timesteps    | 198000   |
# | train/                |          |
# |    entropy_loss       | -2.27    |
# |    explained_variance | -3.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39599    |
# |    policy_loss        | 0.278    |
# |    std                | 0.43     |
# |    value_loss         | 0.0632   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 227       |
# |    ep_rew_mean        | -106      |
# | time/                 |           |
# |    fps                | 382       |
# |    iterations         | 39700     |
# |    time_elapsed       | 518       |
# |    total_timesteps    | 198500    |
# | train/                |           |
# |    entropy_loss       | -2.27     |
# |    explained_variance | -2.51e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39699     |
# |    policy_loss        | -2.09     |
# |    std                | 0.431     |
# |    value_loss         | 1.79      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 227      |
# |    ep_rew_mean        | -106     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39800    |
# |    time_elapsed       | 520      |
# |    total_timesteps    | 199000   |
# | train/                |          |
# |    entropy_loss       | -2.27    |
# |    explained_variance | -428     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39799    |
# |    policy_loss        | -7.59    |
# |    std                | 0.431    |
# |    value_loss         | 6.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 39900    |
# |    time_elapsed       | 521      |
# |    total_timesteps    | 199500   |
# | train/                |          |
# |    entropy_loss       | -2.26    |
# |    explained_variance | -19.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39899    |
# |    policy_loss        | -0.867   |
# |    std                | 0.43     |
# |    value_loss         | 0.282    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 239      |
# |    ep_rew_mean        | -107     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 40000    |
# |    time_elapsed       | 522      |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -2.27    |
# |    explained_variance | 0.152    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39999    |
# |    policy_loss        | -147     |
# |    std                | 0.431    |
# |    value_loss         | 3.78e+03 |
# ------------------------------------
# A2C - Mean reward: -113.73 +/- 10.99

# %%
for name, (mean_reward, std_reward) in results.items():
    print(f"{name} - Mean reward: {mean_reward}")
# Out:
# PPO - Mean reward: 230.3684687
# SAC - Mean reward: -81.8897189
# A2C - Mean reward: -113.7345415

# %%
class JointPenaltyWrapper(gym.RewardWrapper):
    def __init__(self, env, penalty_weight=0.1):
        super().__init__(env)
        self.penalty_weight = penalty_weight
        self.prev_joint_angles = None

    def reset(self, **kwargs):
        result = self.env.reset(**kwargs)
        if isinstance(result, tuple):
            obs = result[0]
        else:
            obs = result
        self.prev_joint_angles = obs[4:8].copy()
        return result

    def step(self, action):
        result = self.env.step(action)
        if len(result) == 5:
            obs, reward, terminated, truncated, info = result
            joint_angles = obs[4:8]
            delta = np.abs(joint_angles - self.prev_joint_angles).sum()
            reward -= self.penalty_weight * delta
            self.prev_joint_angles = joint_angles.copy()
            return obs, reward, terminated, truncated, info
        else:
            obs, reward, done, info = result
            joint_angles = obs[4:8]
            delta = np.abs(joint_angles - self.prev_joint_angles).sum()
            reward -= self.penalty_weight * delta
            self.prev_joint_angles = joint_angles.copy()
            return obs, reward, done, info

# %%
penalty_weight = 0.1
results_penalized = {}

for name, algo in algorithms_dict.items():
    print(f"Training {name} with joint penalty")

    env = JointPenaltyWrapper(gym.make(env_id), penalty_weight=penalty_weight)
    model = algo("MlpPolicy", env, verbose=1)
    model.learn(total_timesteps=timesteps)
    mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=eval_episodes)
    results_penalized[name] = (mean_reward, std_reward)
    print(f"{name} (penalized) - Mean reward: {mean_reward}")
    env.close()
# Out:
# Training PPO with joint penalty
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 842      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    fps             | 894      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | -213        |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009140572 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.0224      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00819    |
# |    std                  | 0.999       |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 443         |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009775811 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.0968      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 1           |
# |    value_loss           | 33.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -176         |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0026090816 |
# |    clip_fraction        | 0.00288      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | -0.00179     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00378     |
# |    std                  | 1            |
# |    value_loss           | 249          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 534         |
# |    ep_rew_mean          | -180        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011389025 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00868    |
# |    std                  | 0.998       |
# |    value_loss           | 27.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013911174 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.985       |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 481          |
# |    ep_rew_mean          | -172         |
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 7            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0055116983 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00446     |
# |    std                  | 0.986        |
# |    value_loss           | 90           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 558          |
# |    ep_rew_mean          | -179         |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 8            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0076152775 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.62        |
# |    explained_variance   | 0.478        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.7         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00743     |
# |    std                  | 0.99         |
# |    value_loss           | 71.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 559         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 9           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017263208 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.342       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.979       |
# |    value_loss           | 0.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 591         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 10          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009494077 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.58       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00914    |
# |    std                  | 0.976       |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 11          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014129297 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.256       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.962       |
# |    value_loss           | 0.615       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | -176        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007569213 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00605    |
# |    std                  | 0.959       |
# |    value_loss           | 34.6        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 667       |
# |    ep_rew_mean          | -179      |
# | time/                   |           |
# |    fps                  | 549       |
# |    iterations           | 13        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0110361 |
# |    clip_fraction        | 0.129     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.48     |
# |    explained_variance   | 0.881     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.24      |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.0103   |
# |    std                  | 0.95      |
# |    value_loss           | 1.42      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 675         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 14          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011952154 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.939       |
# |    value_loss           | 1.31        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 697          |
# |    ep_rew_mean          | -177         |
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 15           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0071831625 |
# |    clip_fraction        | 0.0931       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00639     |
# |    std                  | 0.935        |
# |    value_loss           | 13.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 724        |
# |    ep_rew_mean          | -176       |
# | time/                   |            |
# |    fps                  | 553        |
# |    iterations           | 16         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01289165 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.37      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.207      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.924      |
# |    value_loss           | 0.816      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 730         |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 17          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008799879 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00881    |
# |    std                  | 0.92        |
# |    value_loss           | 12.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | -174        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 18          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007064768 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.32       |
# |    explained_variance   | -0.092      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.915       |
# |    value_loss           | 33.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 765         |
# |    ep_rew_mean          | -174        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 19          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009461697 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.909       |
# |    value_loss           | 0.219       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 20          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011227218 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.039       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.896       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 787         |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 21          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007205697 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.22       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00612    |
# |    std                  | 0.896       |
# |    value_loss           | 42.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 776         |
# |    ep_rew_mean          | -168        |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 22          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009181647 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0499      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00987    |
# |    std                  | 0.87        |
# |    value_loss           | 0.196       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 23           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0050821295 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.1         |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.53         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00773     |
# |    std                  | 0.869        |
# |    value_loss           | 18.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 817         |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 24          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010223186 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0709      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.846       |
# |    value_loss           | 0.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 830         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 25          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006353352 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0985      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00789    |
# |    std                  | 0.84        |
# |    value_loss           | 0.233       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 842         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 26          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013635309 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0882      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.82        |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 843         |
# |    ep_rew_mean          | -164        |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 27          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008663955 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0729      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00713    |
# |    std                  | 0.803       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 866         |
# |    ep_rew_mean          | -163        |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 28          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008342699 |
# |    clip_fraction        | 0.0755      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.0131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.23        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.8         |
# |    value_loss           | 27.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 877         |
# |    ep_rew_mean          | -162        |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 29          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010823382 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0587      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.78        |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 888         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 30          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010827649 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00911     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.778       |
# |    value_loss           | 0.0606      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 898         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 31          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009171136 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0195      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.768       |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | -160        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 32          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010163261 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00828    |
# |    std                  | 0.76        |
# |    value_loss           | 0.0442      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 927         |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 33          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008562993 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0197      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.753       |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 34          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008433284 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.742       |
# |    value_loss           | 0.0525      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 35          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010930389 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.727       |
# |    value_loss           | 0.0793      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 36          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.014774736 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00978     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.721       |
# |    value_loss           | 0.0601      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | -155        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 37          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006279359 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0177      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.714       |
# |    value_loss           | 0.0423      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 945          |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 38           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0051625567 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.68         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00536     |
# |    std                  | 0.714        |
# |    value_loss           | 8.57         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 961         |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 39          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005463194 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.34        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00665    |
# |    std                  | 0.715       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | -151         |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 40           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0066188946 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.166        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00702     |
# |    std                  | 0.715        |
# |    value_loss           | 1.44         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 41          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007135919 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.715       |
# |    value_loss           | 5.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 42          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011310732 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | -0.631      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0753      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.707       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 43          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010630325 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.191      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.695       |
# |    value_loss           | 0.0975      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | -148         |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 44           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0094858175 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00306     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0123      |
# |    std                  | 0.684        |
# |    value_loss           | 0.0685       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 981         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 45          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010188486 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0474      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.677       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 987         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 46          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008385436 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 0.676       |
# |    value_loss           | 4.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 47          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010934429 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00467    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00901    |
# |    std                  | 0.667       |
# |    value_loss           | 0.0731      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 48          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013677098 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0131      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.658       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 49          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011406596 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0187      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.65        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 50          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011870377 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0471      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.642       |
# |    value_loss           | 0.152       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 51          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.012875972 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0185      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.633       |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 52          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010585301 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0849      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.629       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 556          |
# ...
# | rollout/              |          |
# |    ep_len_mean        | 371      |
# |    ep_rew_mean        | -92.1    |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 37700    |
# |    time_elapsed       | 437      |
# |    total_timesteps    | 188500   |
# | train/                |          |
# |    entropy_loss       | 6.04     |
# |    explained_variance | -0.0076  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37699    |
# |    policy_loss        | -0.0689  |
# |    std                | 0.0544   |
# |    value_loss         | 0.000169 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 371      |
# |    ep_rew_mean        | -92.1    |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 37800    |
# |    time_elapsed       | 438      |
# |    total_timesteps    | 189000   |
# | train/                |          |
# |    entropy_loss       | 6.05     |
# |    explained_variance | -0.274   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37799    |
# |    policy_loss        | -0.0552  |
# |    std                | 0.0543   |
# |    value_loss         | 0.000157 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 371      |
# |    ep_rew_mean        | -92.1    |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 37900    |
# |    time_elapsed       | 440      |
# |    total_timesteps    | 189500   |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | -1.18    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37899    |
# |    policy_loss        | 0.0486   |
# |    std                | 0.0536   |
# |    value_loss         | 7.1e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 356      |
# |    ep_rew_mean        | -92.7    |
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 38000    |
# |    time_elapsed       | 441      |
# |    total_timesteps    | 190000   |
# | train/                |          |
# |    entropy_loss       | 6.1      |
# |    explained_variance | 0.338    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 37999    |
# |    policy_loss        | -4.13    |
# |    std                | 0.0537   |
# |    value_loss         | 0.473    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 356      |
# |    ep_rew_mean        | -92.7    |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 38100    |
# |    time_elapsed       | 443      |
# |    total_timesteps    | 190500   |
# | train/                |          |
# |    entropy_loss       | 6.11     |
# |    explained_variance | -3.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38099    |
# |    policy_loss        | 0.0284   |
# |    std                | 0.0536   |
# |    value_loss         | 8.97e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 356      |
# |    ep_rew_mean        | -92.7    |
# | time/                 |          |
# |    fps                | 429      |
# |    iterations         | 38200    |
# |    time_elapsed       | 445      |
# |    total_timesteps    | 191000   |
# | train/                |          |
# |    entropy_loss       | 6.12     |
# |    explained_variance | -1.76    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38199    |
# |    policy_loss        | 0.0598   |
# |    std                | 0.0533   |
# |    value_loss         | 9.36e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 356      |
# |    ep_rew_mean        | -92.7    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38300    |
# |    time_elapsed       | 446      |
# |    total_timesteps    | 191500   |
# | train/                |          |
# |    entropy_loss       | 6.14     |
# |    explained_variance | -0.0578  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38299    |
# |    policy_loss        | -0.183   |
# |    std                | 0.053    |
# |    value_loss         | 0.000904 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 368      |
# |    ep_rew_mean        | -91.9    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38400    |
# |    time_elapsed       | 447      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | -3.64    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38399    |
# |    policy_loss        | 8.97     |
# |    std                | 0.0527   |
# |    value_loss         | 3.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 344      |
# |    ep_rew_mean        | -92.4    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38500    |
# |    time_elapsed       | 449      |
# |    total_timesteps    | 192500   |
# | train/                |          |
# |    entropy_loss       | 6.17     |
# |    explained_variance | -2.74    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38499    |
# |    policy_loss        | -0.156   |
# |    std                | 0.0526   |
# |    value_loss         | 0.00418  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 344      |
# |    ep_rew_mean        | -92.4    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38600    |
# |    time_elapsed       | 450      |
# |    total_timesteps    | 193000   |
# | train/                |          |
# |    entropy_loss       | 6.19     |
# |    explained_variance | -0.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38599    |
# |    policy_loss        | 0.193    |
# |    std                | 0.0524   |
# |    value_loss         | 0.0012   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 344      |
# |    ep_rew_mean        | -92.4    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38700    |
# |    time_elapsed       | 451      |
# |    total_timesteps    | 193500   |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 0.0367   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38699    |
# |    policy_loss        | 0.0944   |
# |    std                | 0.052    |
# |    value_loss         | 0.000311 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 356      |
# |    ep_rew_mean        | -91.7    |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38800    |
# |    time_elapsed       | 453      |
# |    total_timesteps    | 194000   |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | -7.65    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38799    |
# |    policy_loss        | -0.412   |
# |    std                | 0.0519   |
# |    value_loss         | 0.0126   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 342      |
# |    ep_rew_mean        | -92      |
# | time/                 |          |
# |    fps                | 428      |
# |    iterations         | 38900    |
# |    time_elapsed       | 454      |
# |    total_timesteps    | 194500   |
# | train/                |          |
# |    entropy_loss       | 6.26     |
# |    explained_variance | -0.33    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38899    |
# |    policy_loss        | 2.28     |
# |    std                | 0.0516   |
# |    value_loss         | 0.279    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | -94.1    |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 39000    |
# |    time_elapsed       | 455      |
# |    total_timesteps    | 195000   |
# | train/                |          |
# |    entropy_loss       | 6.25     |
# |    explained_variance | 0.485    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 38999    |
# |    policy_loss        | -0.752   |
# |    std                | 0.0516   |
# |    value_loss         | 0.0194   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 291      |
# |    ep_rew_mean        | -94.8    |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 39100    |
# |    time_elapsed       | 456      |
# |    total_timesteps    | 195500   |
# | train/                |          |
# |    entropy_loss       | 6.26     |
# |    explained_variance | -0.265   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39099    |
# |    policy_loss        | 9.74     |
# |    std                | 0.0516   |
# |    value_loss         | 2.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 293      |
# |    ep_rew_mean        | -94.6    |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 39200    |
# |    time_elapsed       | 458      |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | 6.27     |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39199    |
# |    policy_loss        | 1.57     |
# |    std                | 0.0515   |
# |    value_loss         | 0.0635   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | -95.6    |
# | time/                 |          |
# |    fps                | 427      |
# |    iterations         | 39300    |
# |    time_elapsed       | 460      |
# |    total_timesteps    | 196500   |
# | train/                |          |
# |    entropy_loss       | 6.26     |
# |    explained_variance | -0.00177 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39299    |
# |    policy_loss        | 340      |
# |    std                | 0.0515   |
# |    value_loss         | 4.86e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 272      |
# |    ep_rew_mean        | -97.8    |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 39400    |
# |    time_elapsed       | 461      |
# |    total_timesteps    | 197000   |
# | train/                |          |
# |    entropy_loss       | 6.23     |
# |    explained_variance | 0.126    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39399    |
# |    policy_loss        | 10.2     |
# |    std                | 0.052    |
# |    value_loss         | 2.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 272      |
# |    ep_rew_mean        | -98.8    |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 39500    |
# |    time_elapsed       | 463      |
# |    total_timesteps    | 197500   |
# | train/                |          |
# |    entropy_loss       | 6.22     |
# |    explained_variance | 0.797    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39499    |
# |    policy_loss        | 0.133    |
# |    std                | 0.052    |
# |    value_loss         | 0.0382   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 271      |
# |    ep_rew_mean        | -99      |
# | time/                 |          |
# |    fps                | 426      |
# |    iterations         | 39600    |
# |    time_elapsed       | 464      |
# |    total_timesteps    | 198000   |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | 0.502    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39599    |
# |    policy_loss        | -0.529   |
# |    std                | 0.052    |
# |    value_loss         | 0.0115   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 271      |
# |    ep_rew_mean        | -99      |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 39700    |
# |    time_elapsed       | 466      |
# |    total_timesteps    | 198500   |
# | train/                |          |
# |    entropy_loss       | 6.25     |
# |    explained_variance | -0.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39699    |
# |    policy_loss        | 0.178    |
# |    std                | 0.0516   |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 271      |
# |    ep_rew_mean        | -99      |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 39800    |
# |    time_elapsed       | 467      |
# |    total_timesteps    | 199000   |
# | train/                |          |
# |    entropy_loss       | 6.24     |
# |    explained_variance | -32.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39799    |
# |    policy_loss        | 1.31     |
# |    std                | 0.0518   |
# |    value_loss         | 0.066    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 287      |
# |    ep_rew_mean        | -98.9    |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 39900    |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 199500   |
# | train/                |          |
# |    entropy_loss       | 6.23     |
# |    explained_variance | 0.616    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39899    |
# |    policy_loss        | -2.27    |
# |    std                | 0.0519   |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 258      |
# |    ep_rew_mean        | -100     |
# | time/                 |          |
# |    fps                | 425      |
# |    iterations         | 40000    |
# |    time_elapsed       | 470      |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | 6.26     |
# |    explained_variance | 0.613    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 39999    |
# |    policy_loss        | -0.776   |
# |    std                | 0.0516   |
# |    value_loss         | 0.0147   |
# ------------------------------------
# A2C (penalized) - Mean reward: -122.5672857

# %%
for name, (mean_reward, std_reward) in results.items():
    print(f"{name} - Mean reward: {mean_reward}")
# Out:
# PPO - Mean reward: 230.3684687
# SAC - Mean reward: -81.8897189
# A2C - Mean reward: -113.7345415

# %% [markdown]
# ### Unexpeted Output
# **In the [15] you have printed the previous reward without the penlized rewards**
#
# ### Suggestions
# - You can create a graph to show the reward differences between the default and penalized reward
# - - Creating GIFs of robot simulations with different reward types in the same environment, shown side by side, can **enhance your understanding** of what actually changed — whether the robot **truly learned something new** after the reward modification.
